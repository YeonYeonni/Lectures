# %% [markdown]
# https://pytorch.org/vision/0.8/_modules/torchvision/models/resnet.html

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Basic Block
#     - VGG 구조와 동일하게 모두 3x3 conv 구조
#
# - Bottlenet Block
#     - 256d가 들어왔을때, 64채널로 줄여줌
#     - 1x1 -> 3x3 -> 1x1
