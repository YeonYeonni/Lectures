# %% [markdown]
# ### Local Image Features
#
# ![image.png](attachment:image.png)
#
# - An interesting part of and image

# %% [markdown]
# ### Use of Local Image Features
#
# - Image representation
#
#
# - Image-level descriptor by aggregating local faetures
#     - Image -> Bag of Visual Words
#
#
# - Object appearance modeling
#     - Insensitive to pose variation
#         - local feature를 이용해 물체가 어느 방향을 바라보든 object를 찾아낼 수 있음
#     - Robust to partial occlusion
#         - object의 일부 정보만 가지고도 위치를 찾아낼 수 있음
#
#
# - Finding matches between multiple views
#     - Stereo matching
#     - 3D reconstruction
#         - depth를 알아내 reconstruction
#     - Image stitching
#         - 두 이미지에서 대응점을 붙여 파노라마를 만듦

# %% [markdown]
# ### What Is a Good Local Feature?
#
# - Conditions to be a good local visual-feature
#
#
# - Saliency : A feature includes an **interesting part** of an image
# - Locality : A feature occupies **a small area** in an image
#     - 고전적 컴퓨터 비전의 정의
#     - Neural Network의 Receptive Field가 점점 넓어지면서 Hight-Level Sementics를 이미 Encoding.
#     - Local Feature도 shallow한 layer에서 이미 Encoding 되면서 forward.
#     - 따라서 small area 컨셉은 obsolete.
#
# - Repeatability : The same feature should be detected at the same location in many images of the same scene **despite various geometric and photometric transformations**
#     - geometric : flip, rotate 등
#     - photometric : jpeg compression 등

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - Be unambiguous for matching
#     - Generally, it is better to the order: Corner > Edge >>> Textureless region

# %% [markdown]
# ### Good Local Feature (Interest Point)
#
# - Interest Point
#     -
